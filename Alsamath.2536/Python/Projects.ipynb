# %%
#Triangle 
side1=input("Enter your first side of the triangle:")
side2=input("Enter your second side of the triangle:")
side3=input("Enter your third side of the triangle:")
if(str(side1).replace('.','').isdigit() and 
   str(side2).replace('.','').isdigit() and 
   str(side3).replace('.','').isdigit()):
    s1=float(side1)
    s2=float(side2)
    s3=float(side3)

    if((s1+s2)>s3 and (s2+s3)>s1 and (s3+s1)>s2 and s1>0 and s2>0 and s3>0):
        if(s1==s2 and s2==s3 and s3==s1):
            print("Equilateral")
        elif(s1==s2 or s2==s3 or s3==s1):
            print("Isoceles")
        else:
            print("Scalene")
    else:
        print("Invalid Triangle")
else:
    print("Invalid")

# %%
#Tip calculator
print("_______________Tip Calculator___________________")
print("\nHello I am here to help you to calculate your bills ")
print("\nGive me the below details")
total_bill=input("Enter your total bill in rupees:Rs.") 
tips=input("How much tips you decided to give (in percentage)% ?")
members=input("How many members are there to split the bill with tip?")

if(total_bill.replace(".","").isdigit() and tips.replace(".","").isdigit() and members.replace(".","").isdigit()):
    total_bill=float(total_bill)
    tips=float(tips)
    members=int(members)
    if(total_bill>0 and tips>0 and members>0):
        
        tip_amount=total_bill*(tips/100)
        members_tip_amount=tip_amount/members
        members_bill_amount=total_bill/members
        
        members_amount=round(members_tip_amount + members_bill_amount)
        
        if(members_amount>=100 and (tips>0 and tips<50) and members_tip_amount>5 and total_bill>0):
       
            print(members_amount)
    
        else:
            print("members amount",members_amount)
            print("members tip amount",members_tip_amount)
            print("members total bill amount ",members_bill_amount)
            print("tips",tips)
            print("tip amount",tip_amount)
            print("You have entered some invalid data recheck with it")
    else:
        print("Value must be greater than zero")
else:
    print("Invalid data")

# %%
#Treasure land 
print("                      |\/\/\/\/\/\/\/|                  ")
print("\n                      |      /\      |                  ")
print("\n                      |     |  |     |                   ")
print("\n                      |______\/______|                  ")
print("\n ______________Welcome to the Treasure Island______________")
"\n"
print("Note:Follow the instruction and select one from the given option ")
print("\nLets Start !!!!!!")
"\n"
print("A group of people is travelling towards the search of treasure")
print("Help them to find the treasure ")
"\n"
print("Oops!! They stucked on a decision")
direction=input("Help them on that decision do they need to go Right : Left ? ")
direction=direction.capitalize()
if(direction=="Right"):
    print("Great !!! Now they came to a protector of that place")
    print("He will ask the guys a question")
    test1=input("\nHere is the question : White pearls in a green substance?")
    test1=test1.lower()
    if(test1=="ladies fingers" or "ladies finger"):
        print("Correct Answer : You can go now ")

        print("\nNow the people are moving towards a mountain ")
        print("Here comes the giant man He have a question ")
        test2=int(input("\nThe Question is: A number which divides all the number"))
        if(test2==1):
            print("Here is your treasure but it is locked")
            test3=int(input("The password is : 1 3 5 7 ?, Now find the next number "))
            if(test3==9):
                print("Yeah you came to an end ")
                print("\nCongratulation ! ! !  You found the treasure")
    else:
        print("Wrong Answer : Game Over !!!")
else:
    print("Sorry, You crossed the war zone and got killed")
    print("\nGamer Over")
# Out:
#                       |\/\/\/\/\/\/\/|
#
#                       |      /\      |
#
#                       |     |  |     |
#
#                       |______\/______|
#
#  ______________Welcome to the Treasure Island______________
# Note:Follow the instruction and select one from the given option
#
# Lets Start !!!!!!
# A group of people is travelling towards the search of treasure
# Help them to find the treasure
# Oops!! They stucked on a decision
# Help them on that decision do they need to go Right : Left ?  left
# Sorry, You crossed the war zone and got killed
#
# Gamer Over

# %%
#Rock,paper,scissor
#Rock,paper,scissor 
import random
user_input=input("Enter 0 for rock : Enter 1 for paper: Enter 2 for scissor" )
zero="    _______\n---'   ____)\n      (_____)\n      (_____)\n      (____)\n---.__(___)"
one ="    _______\n---   ____ )____\n          ______)\n          _______)\n         _______)\n---.__________)"
two="    _______\n---'   ____)____\n          ______)\n       __________)\n      (____)\n---.__(___)"


if(user_input.isdigit()):
    value=int(user_input)
    computer_value=random.randint(0,2)
    if(value>=0 and value <=2 ):
       if(value==0 and computer_value==0):
           print("Your input : \n",zero)
           print("Computer input: \n",zero)
           print("\nThe Game is Draw")
       elif(value==1 and computer_value==1):
            print("Your input : \n",one)
            print("Computer input: \n",one)
            print("\nThe Game is Draw")
       elif(value==2 and computer_value==2):
            print("Your input : \n",two)
            print("Computer input: \n",two)
            print("\nThe Game is Draw")
       elif(value==0 and computer_value==1):
            print("Your input: \n",zero)
            print("Computer input: \n",one)
            print("Computer wins")
       elif(value==1 and  computer_value==0):
             print("Your input: \n",one)
             print("Computer input: \n",zero)
             print("You wins")
       elif(value==0 and  computer_value==2):
             print("Your input: \n",zero)
             print("Computer input: \n",two)
             print("You wins")
       elif(value==2 and  computer_value==0):
             print("Your input: \n",one)
             print("Computer input: \n",zero)
             print("Computer wins")
       elif(value==1 and  computer_value==2):
             print("Your input: \n",one)
             print("Computer input: \n",zero)
             print("You wins")
       elif(value==2 and  computer_value==1):
             print("Your input: \n",one)
             print("Computer input: \n",zero)
             print("You wins")
    

    else:
       print("Invalid")
