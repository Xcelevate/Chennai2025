# %%
### rock , paper , scissor;

import random
print("rock means------( 0 )")
print("scissor means---( 1 )") 
print("paper means-----( 2 )")


your_choice = (input("---"))

com_choice = random.randint(0,2)

if(your_choice.isdigit() ):
    your_choice=int(your_choice)
    if(0 <= your_choice <3):
        x=your_choice
        if(x==0): 
            print("""
    _______
---'   ____)
      (_____)
      (_____)
      (____)
---.__(___)
""")

        elif(x==1):
            print("""
    _______
---'   ____)____
          ______)
       __________)
      (____)
---.__(___)
""")

        elif(x==2):
            print("""
    _______
---'   ____)____
          ______)
          _______)
         _______)
---.__________)
""")
        print( "Computer chose:")
        x=com_choice
        if(x==0): 
            print("""
    _______
---'   ____)
      (_____)
      (_____)
      (____)
---.__(___)
""")

        elif(x==1):
            print("""
    _______
---'   ____)____
          ______)
       __________)
      (____)
---.__(___)
""")

        elif(x==2):
            print("""
    _______
---'   ____)____
          ______)
          _______)
         _______)
---.__________)
""")
        print()
        
        if(your_choice == 0):
            if(com_choice ==1):
               print("you win")
            elif(com_choice == 2):
               print("computer win")
            else:
               print("it's draw")
            
        elif(your_choice == 1):
            if(com_choice ==2):
                print("you win")
            elif(com_choice == 0):
                print("computer win")
            else:
                print("it's draw")
                
        else:
            if(com_choice ==0):
                print("you win")
            elif(com_choice == 1):
                print("computer win")
            else:
                print("it's draw")
    else:
        print("enter 0 or 1 or 2")
else:
    print("Oops,Your value is not matching. \nPlease enter the correct value.")
# Out:
# rock means------( 0 )
# scissor means---( 1 )
# paper means-----( 2 )
# --- 2
#     _______
# ---'   ____)____
#           ______)
#           _______)
#          _______)
# ---.__________)
#
# Computer chose:
#
#     _______
# ---'   ____)
#       (_____)
#       (_____)
#       (____)
# ---.__(___)
#
#
# you win

# %%
#### treasure island;



print("""
*******************************************************************************
          |                   |                  |                     |
 _________|________________.=""_;=.______________|_____________________|_______
|                   |  ,-"_,=""     '"=.|                  |
|___________________|__"=._o'"-._        '"=.______________|___________________
          |                '"=._o'"=._      _'"=._                     |
 _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
|                   |    __.--" , ; '"=._o." ,-"-._ ".   |
|___________________|_._"  ,. .' ' '' ,  '"-._"-._   ". '__|___________________
          |           |o'"=._' , "' '; .". ,  "-._"-._; ;              |
 _________|___________| ;'-.o'"=._; ." ' ''."' . "-._ /_______________|_______
|                   | |o;    '"-.o'"=._''  '' " ,__.--o;   |
|___________________|_| ;     (#) '-.o '"=.'_.--"_o.-; ;___|___________________
____/______/______/___|o;._    "      '".o|o_.--"    ;o;____/______/______/____
/______/______/______/_"=._o--._        ; | ;        ; ;/______/______/______/_
____/______/______/______/__"=._o--._   ;o|o;     _._;o;____/______/______/____
/______/______/______/______/____"=._o._; | ;_.--"o.--"_/______/______/______/_
____/______/______/______/______/_____"=.o|o_.--""___/______/______/______/____
/______/______/______/______/______/______/______/______/______/______/_____ /
*******************************************************************************
Welcome to Treasure Island.
Your mission is to find the treasure.""""")
print(""" You're at a cross road. Where do you want to go?
      Type "left" or "right" """)

direc = input()
direc = direc.strip()
if(direc.lower() == "left"):
    print(""" You've come to a lake. There is an island in the middle of the lake.
  Type "wait" to wait for a boat. Type "swim" to swim across.""")
    action = input()
    action = action.strip()
    if(action.lower() == "wait"):
        print("""You arrive at the island unharmed. There is a house with 3 doors.
  One red, one white and one green. Which colour do you choose? """)

        door = input()
        door = door.strip()
        if(door.lower() == "red"):
            print("It's a room full of fire. Game Over.")
        elif(door.lower() == "white"):
            print("You found the treasure! You Win!")
        elif(door.lower() == "green"):
            print("You enter a room of beasts. Game Over.")
        else:
            print("Run again.enter the valid value showing above")
            

    elif(action.lower() == "swim"):
        print("You get attacked by an angry trout. Game Over.")
    else:
        print(""" Run again and enter , either "swim" or "wait" """)
        

elif(direc.lower() == "right"):
    print("You fell into a hole. Game Over.")

else:
    print(""" Run again and enter , either "left" or "right" """)
# Out:
# *******************************************************************************
#           |                   |                  |                     |
#  _________|________________.=""_;=.______________|_____________________|_______
# |                   |  ,-"_,=""     '"=.|                  |
# |___________________|__"=._o'"-._        '"=.______________|___________________
#           |                '"=._o'"=._      _'"=._                     |
#  _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
# |                   |    __.--" , ; '"=._o." ,-"-._ ".   |
# |___________________|_._"  ,. .' ' '' ,  '"-._"-._   ". '__|___________________
#           |           |o'"=._' , "' '; .". ,  "-._"-._; ;              |
#  _________|___________| ;'-.o'"=._; ." ' ''."' . "-._ /_______________|_______
# |                   | |o;    '"-.o'"=._''  '' " ,__.--o;   |
# |___________________|_| ;     (#) '-.o '"=.'_.--"_o.-; ;___|___________________
# ...

# %%
#### tips calculator



print("Welcome to the tip calculator!")
amount = input("What was the total bill?")
if(amount.replace(".","").isdigit()):
    amount=float(amount)
    if(amount >=100):
        tip = input("How much percentage of tip would you like to give?")
        if(tip.replace(".","").isdigit()):
            tip = float(tip)
            if( 0< tip <50):
                tip_val = (tip * amount)/100
                person = input("How many people to split the bill?")
                if(person.isdigit()):
                    person = int(person)
                    if(person > 0):
                        if((tip_val / person) > 5):
                            total = round(amount + tip_val)
                            print("Each person should pay:",round((total / person),2))
                        else:
                            print("give atleast 5 rupees tip,so reduce the people count")
                else:
                    print("enter the valid details")
            else:
                print("Sorry,Tip shoud be between 1 and 50")
        else:
            print("enter the valid tip.")
    else:
        print("Sorry,Minimum amount is above 100.")
else:
    print("enter the valid bill")
# Out:
# Welcome to the tip calculator!
