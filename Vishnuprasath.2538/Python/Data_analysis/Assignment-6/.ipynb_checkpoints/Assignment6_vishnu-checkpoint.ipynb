# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('assignment6_customer_analytics(in).csv')
df
# Out:
#      CustomerID  Age  Income  PurchaseCount  AvgOrderValue Region  \
# 0          2001   44  111365             23           1000   East
# 1          2002   25  139014             45           3184   West
# 2          2003   42  185806              2           2109   East
# 3          2004   63   97588             41            341  South
# 4          2005   21   88646             21           2485   East
# ..          ...  ...     ...            ...            ...    ...
# 145        2146   35   34715             38           2681   West
# 146        2147   19   44169             15           3968  South
# 147        2148   66  143413             21           3637  South
# 148        2149   30  172235             10           4965  South
# 149        2150   21  144264             23           4408  North
#
#         Category  CustomerRating  YearsAsCustomer
# 0       Software             3.2                1
# 1       Software             3.6                7
# 2    Electronics             4.4               13
# 3    Accessories             3.6                5
# 4       Software             3.8               13
# ..           ...             ...              ...
# 145  Electronics             4.7                3
# 146  Electronics             4.0                5
# 147  Electronics             4.6               11
# 148  Electronics             2.0               12
# 149  Accessories             2.5                2
#
# [150 rows x 9 columns]

# %% [markdown]
# ### Q6.1: Histogram with KDE
# #### Create a histogram with KDE showing the distribution of customer ages using Seaborn.

# %%
sns.set_style("darkgrid")

# %%
sns.histplot(data=df, x="Age", kde=True)
plt.title("Distribution of Customer Ages")
plt.xlabel("Age")
plt.ylabel("Number of Customers")
plt.show()

# %% [markdown]
# ### Q6.2: Count Plot
# #### Create a count plot showing the number of customers per region.

# %%
sns.countplot(data = df, x='Region', palette='Set1')
plt.title('Number of customers per region')
plt.xlabel('Region')
plt.ylabel('Number of customers')
plt.show()
# Out:
# C:\Users\vishnu prasath\AppData\Local\Temp\ipykernel_502808\3916280014.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = df, x='Region', palette='Set1')

# %% [markdown]
# ### Q6.3: Scatter Plot with Hue
# #### Create a scatter plot with Age vs Income, colored by Region using Seaborn.

# %%
sns.scatterplot(data=df, x='Age', y='Income',hue='Region')
plt.title('Age vs Income by region')
plt.xlabel('Age')
plt.ylabel('Income')
plt.show()

# %% [markdown]
# ### Q6.4: Box Plot
# #### Create a box plot showing the distribution of PurchaseCount across regions.

# %%
sns.boxplot(data=df, x='Region', y='PurchaseCount', palette='Set3')
plt.title('PurchaseCount across regions')
plt.xlabel('Regiopn')
plt.ylabel('PurchaseCount')
plt.show()
# Out:
# C:\Users\vishnu prasath\AppData\Local\Temp\ipykernel_502808\1983437856.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Region', y='PurchaseCount', palette='Set3')

# %% [markdown]
# ### Q6.5: Heatmap
# #### Create a heatmap showing correlations between numeric columns.

# %%
col = df[['CustomerID', 'Age', 'Income', 'PurchaseCount', 'AvgOrderValue', 'CustomerRating', 'YearsAsCustomer']]

# %%
correlation = col.corr()
correlation
# Out:
#                  CustomerID       Age    Income  PurchaseCount  AvgOrderValue  \
# CustomerID         1.000000  0.110084 -0.051515       0.008794       0.042586
# Age                0.110084  1.000000 -0.046371      -0.000361      -0.152008
# Income            -0.051515 -0.046371  1.000000      -0.016140      -0.031728
# PurchaseCount      0.008794 -0.000361 -0.016140       1.000000      -0.005728
# AvgOrderValue      0.042586 -0.152008 -0.031728      -0.005728       1.000000
# CustomerRating    -0.003264 -0.093142 -0.039247       0.036552       0.041835
# YearsAsCustomer   -0.041085  0.085489  0.050013       0.028422       0.059351
#
#                  CustomerRating  YearsAsCustomer
# CustomerID            -0.003264        -0.041085
# Age                   -0.093142         0.085489
# Income                -0.039247         0.050013
# PurchaseCount          0.036552         0.028422
# AvgOrderValue          0.041835         0.059351
# CustomerRating         1.000000         0.091205
# YearsAsCustomer        0.091205         1.000000

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(correlation, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap of Customer Data")
plt.show()

# %% [markdown]
# ### Q6.6: Bar Plot with CI
# #### Create a bar plot showing average CustomerRating by Category with confidence intervals.

# %%
sns.barplot(data=df, x='Category', y='CustomerRating', palette='Set1')
plt.title('Average CustomerRating by Category')
plt.xlabel('Category')
plt.ylabel('Average CustomerRating')
plt.show()
# Out:
# C:\Users\vishnu prasath\AppData\Local\Temp\ipykernel_502808\3241651154.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='Category', y='CustomerRating', palette='Set1')

# %% [markdown]
# ### Q6.7: Pair Plot
# #### Create a pair plot for Age, Income, PurchaseCount, CustomerRating colored by Region.

# %%
sns.pairplot(df, vars=['Age', 'Income', 'PurchaseCount', 'CustomerRating'], hue='Region')
plt.show()

# %%
sns.pairplot(df, vars=['Age', 'Income', 'PurchaseCount', 'CustomerRating'], hue='Region')
plt.suptitle('Pair Plot: Customer Metrics by Region', y=1.01, fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Q6.8: Violin Plot
# #### Create a violin plot showing the distribution of AvgOrderValue by Region.

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(data=df, x='Region', y='AvgOrderValue', palette ='muted')
plt.title('Distribution of AvgOrderValue by Region')
plt.xlabel('Region')
plt.ylabel('AvgOrderValue')
plt.show()
# Out:
# C:\Users\vishnu prasath\AppData\Local\Temp\ipykernel_502808\1353260098.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Region', y='AvgOrderValue', palette ='muted')

# %% [markdown]
# ### Q6.9: Clustermap
# #### Create a clustermap (hierarchical heatmap) of customer metrics.

# %%
sns.clustermap(correlation, cmap='coolwarm', standard_scale=1)
plt.show()

# %% [markdown]
# ### Q6.10: Joint Plot
# #### Create a joint plot showing Age vs CustomerRating relationship with marginal distributions.

# %%
sns.jointplot(data=df, x='Age', y='CustomerRating', kind='scatter')
plt.show()

# %% [markdown]
# ### Challenge Extension
# #### Challenge 1: Create a custom color palette and apply to multiple plots.

# %%
custom_palette = ["#4C72B0", "#55A868", "#C44E52", "#8172B2"]

# %%
sns.countplot(data = df, x='Region', palette=custom_palette)
plt.title('Number of customers per region')
plt.xlabel('Region')
plt.ylabel('Number of customers')
plt.show()

sns.boxplot(data=df, x='Region', y='PurchaseCount', palette=custom_palette)
plt.title('PurchaseCount across regions')
plt.xlabel('Regiopn')
plt.ylabel('PurchaseCount')
plt.show()

sns.barplot(data=df, x='Category', y='CustomerRating', palette=custom_palette)
plt.title('Average CustomerRating by Category')
plt.xlabel('Category')
plt.ylabel('Average CustomerRating')
plt.show()
# Out:
# C:\Users\vishnu prasath\AppData\Local\Temp\ipykernel_560800\377848301.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = df, x='Region', palette=custom_palette)
# C:\Users\vishnu prasath\AppData\Local\Temp\ipykernel_560800\377848301.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Region', y='PurchaseCount', palette=custom_palette)
# C:\Users\vishnu prasath\AppData\Local\Temp\ipykernel_560800\377848301.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='Category', y='CustomerRating', palette=custom_palette)
# C:\Users\vishnu prasath\AppData\Local\Temp\ipykernel_560800\377848301.py:13: UserWarning: The palette list has more values (4) than needed (3), which may not be intended.
#   sns.barplot(data=df, x='Category', y='CustomerRating', palette=custom_palette)

# %% [markdown]
# #### Challenge 2: Use FacetGrid for complex multi-variable analysis.

# %%
g = sns.FacetGrid(data=df, col="Region", col_wrap=2, height=4, aspect=1)
g.map_dataframe(sns.scatterplot, x="Age", y="Income")
g.set_axis_labels("Age", "Income")
g.set_titles("Region: {col_name}")
plt.show()

# %% [markdown]
# #### Challenge 3: Create regression plots with confidence bands.

# %%
sns.regplot(data=df, x='Age', y='CustomerRating')
plt.title('Age vs Customer Rating with Regression Line')
plt.xlabel('Age')
plt.ylabel('CustomerRating')
plt.show()
