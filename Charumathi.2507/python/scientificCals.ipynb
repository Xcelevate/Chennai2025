# %%
# Scientific Calculator
num1 = input("What is the 1st num?")
a=num1.replace(".","")
a1=a.replace("-","")
if(a1.isdigit()):
    x= float(num1)
    operator = input("What do you want to do?")
    if(operator in("+","-","*","/","//","%","^","!")):
        if(operator=="!"):
            if(x>0):
                out= 1
                for i in range(1,x+1):
                    out *= i
                print(out)
            elif(x==0):
                print(1)
            else:
                print("undefined")               
        else:
            num2 =input("What is your 2nd num?")
            b=num2.replace(".","")
            b1=b.replace("-","")
            if(b1.isdigit()):
                y=float(num2)
                if(operator=="+"):
                    print(x+y)
                elif(operator=="-"):
                    print(x-y)
                elif(operator=="*"):
                    print(x*y)
                elif(operator=="/"):
                    if(y==0):
                        print("infinity")
                    else:
                        print(x/y)
                elif(operator=="//"):
                    if(y==0):
                        print("infinity")
                    else:
                        print(x//y)
                elif(operator=="%"):
                    print(x%y)
                elif(operator=="^"):
                    print(x**y)
                else:
                    print("Enter valid operator \n('+' or '-' or * or '/' or \n '^' (power) or '%'(modulos) or '!'(factorial) or '//'(floor_division))")
            else:
                print("Only digits are acceptable")
    else:
        print("('+','-','*','/','//','%','^','!')\n only these operators are acceptable ")
else:
    print("Only digits are acceptable")
print("Thank you for using my cals!")
